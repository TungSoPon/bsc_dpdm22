# %% [markdown]
# <a href="https://colab.research.google.com/github/TungSoPon/bsc_dpdm22/blob/main/Untitled22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##HW3
#  visualize แสดงความสัมพันธ์ ราคา(ตั้งขายและประเมิน)-ความมั่นใจ-ให้คะแนนทรัพย์

# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
# !wget -q https://github.com/Phonbopit/sarabun-webfont/raw/master/fonts/thsarabunnew-webfont.ttf
import matplotlib as mpl
mpl.font_manager.fontManager.addfont('thsarabunnew-webfont.ttf')
mpl.rc('font', family='TH Sarabun New')

# %%
sheet_id = '13tZJ1ZQuO6HWzbuZzabmmF_NnZpLAw2TG_eqN_ExU3U'
sheet_name = 'home'
url1 = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'

# %%
sheet_id = '13tZJ1ZQuO6HWzbuZzabmmF_NnZpLAw2TG_eqN_ExU3U'
sheet_name = 'land'
url2 = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'

# %%
sheet_id = '13tZJ1ZQuO6HWzbuZzabmmF_NnZpLAw2TG_eqN_ExU3U'
sheet_name = 'townhome'
url3 = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'

# %%
sheet_id = '13tZJ1ZQuO6HWzbuZzabmmF_NnZpLAw2TG_eqN_ExU3U'
sheet_name = 'commercial'
url4 = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'

# %%
data1 = pd.read_csv(url1)
data2 = pd.read_csv(url2)
data3 = pd.read_csv(url3)
data4 = pd.read_csv(url4)

# %%
data1_C = data1[['ความมั่นใจในการเมินราคาทรัพย์','ราคาทรัพย์', 'ประเมินราคาซื้อ-ขาย','ให้คะแนนทรัพย์']]
data2_C = data1[['ความมั่นใจในการเมินราคาทรัพย์','ราคาทรัพย์', 'ประเมินราคาซื้อ-ขาย','ให้คะแนนทรัพย์']]
data3_C = data1[['ความมั่นใจในการเมินราคาทรัพย์','ราคาทรัพย์', 'ประเมินราคาซื้อ-ขาย','ให้คะแนนทรัพย์']]
data4_C = data1[['ความมั่นใจในการเมินราคาทรัพย์','ราคาทรัพย์', 'ประเมินราคาซื้อ-ขาย','ให้คะแนนทรัพย์']]

# %%
data3
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 0                1    https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 1                2    https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 2                1    https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
# 3                2    https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
# 4                1    https://nayoo.co/khonkaen/posts/579      ทาวน์โฮม
# ..             ...                                    ...           ...
# 235              2  https://nayoo.co/khonkaen/posts/18547      ทาวน์โฮม
# 236              2  https://nayoo.co/khonkaen/posts/18551      ทาวน์โฮม
# 237              2  https://nayoo.co/khonkaen/posts/19434      ทาวน์โฮม
# 238              2  https://nayoo.co/khonkaen/posts/19501      ทาวน์โฮม
# 239              2  https://nayoo.co/khonkaen/posts/20367      ทาวน์โฮม
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
data3.isnull().any()
# Out:
# ID ผู้ประเมิน                     False
# post id                           False
# property_type                     False
# ความมั่นใจในการเมินราคาทรัพย์     False
# ราคาทรัพย์                        False
# ประเมินราคาซื้อ-ขาย               False
# ปัจจัยในการประเมินราคาซื้อ-ขาย    False
# เหตุผลไม่มั่นใจราคาประเมิน         True
# ให้คะแนนทรัพย์                    False
# Unnamed: 9                         True
# Unnamed: 10                        True
# Unnamed: 11                        True
# Unnamed: 12                        True
# Unnamed: 13                        True
# Unnamed: 14                        True
# Unnamed: 15                        True
# Unnamed: 16                        True
# Unnamed: 17                        True
# Unnamed: 18                        True
# Unnamed: 19                        True
# Unnamed: 20                        True
# Unnamed: 21                        True
# Unnamed: 22                        True
# ...

# %%
data3[['ให้คะแนนทรัพย์']].value_counts().reset_index()[['property_type','ให้คะแนนทรัพย์']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-77-4e767cad2383> in <module>
# ----> 1 data3[['ให้คะแนนทรัพย์']].value_counts().reset_index()[['property_type','ให้คะแนนทรัพย์']]
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ...

# %%
plt.hist([data3['ความมั่นใจในการเมินราคาทรัพย์']])
plt.hist([data3['ให้คะแนนทรัพย์']])
#plt.bar([data3['ราคาทรัพย์']])
#plt.xticks(rotation='vertical')
plt.xticks(rotation='vertical')
# Out:
# ([0, 1, 2, 3, 4, 5], <a list of 6 Text major ticklabel objects>)

# %%
data3.groupby(['ราคาทรัพย์']).mean()
# Out:
#             ID ผู้ประเมิน  ประเมินราคาซื้อ-ขาย  เหตุผลไม่มั่นใจราคาประเมิน  \
# ราคาทรัพย์
# 510000                1.5             510000.0                         NaN
# 544000                1.5             900000.0                         NaN
# 605000                1.5             725000.0                         NaN
# 660000                1.5             675000.0                         NaN
# 715000                1.5             675000.0                         NaN
# ...                   ...                  ...                         ...
# 3410000               1.5            3275000.0                         NaN
# 3630000               1.5            3550000.0                         NaN
# 3850000               1.5            3350000.0                         NaN
# 4400000               1.5            4100000.0                         NaN
# 4730000               1.5            3800000.0                         NaN
#
# ...

# %%
plt.hist([data3['ราคาทรัพย์']])
plt.xticks(rotation='vertical')
# Out:
# (array([      0., 1000000., 2000000., 3000000., 4000000., 5000000.]),
#  <a list of 6 Text major ticklabel objects>)
