# %% [markdown]
# <a href="https://colab.research.google.com/github/TungSoPon/bsc_dpdm22/blob/main/Untitled24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Load google sheet มาตรฐาน

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

# %%
import pandas as pd

# %%
gsht = gc.open_by_key('13tZJ1ZQuO6HWzbuZzabmmF_NnZpLAw2TG_eqN_ExU3U')

# %%
worksheet = gsht.worksheet("land")

# %%
rows = worksheet.get_all_values()
land = pd.DataFrame.from_records(rows)

# %%
land
# Out:
#                  0                                      1              2  \
# 0    ID ผู้ประเมิน                                post id  property_type
# 1               01   https://nayoo.co/khonkaen/posts/1033         ที่ดิน
# 2               02   https://nayoo.co/khonkaen/posts/1033         ที่ดิน
# 3               04   https://nayoo.co/khonkaen/posts/1033         ที่ดิน
# 4               01   https://nayoo.co/khonkaen/posts/1711         ที่ดิน
# ..             ...                                    ...            ...
# 206             01  https://nayoo.co/khonkaen/posts/17093         ที่ดิน
# 207             02  https://nayoo.co/khonkaen/posts/17112         ที่ดิน
# 208             01  https://nayoo.co/khonkaen/posts/17112         ที่ดิน
# 209             02  https://nayoo.co/khonkaen/posts/17145         ที่ดิน
# 210             01  https://nayoo.co/khonkaen/posts/17145         ที่ดิน
#
#                                  3           4                    5  \
# ...

# %%
land.columns = land.iloc[0] #สามารถใส่เองโดยใช้lit
land.head()
# Out:
# 0  ID ผู้ประเมิน                               post id  property_type  \
# 0  ID ผู้ประเมิน                               post id  property_type
# 1             01  https://nayoo.co/khonkaen/posts/1033         ที่ดิน
# 2             02  https://nayoo.co/khonkaen/posts/1033         ที่ดิน
# 3             04  https://nayoo.co/khonkaen/posts/1033         ที่ดิน
# 4             01  https://nayoo.co/khonkaen/posts/1711         ที่ดิน
#
# 0  ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 0  ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย
# 1                         มั่นใจ     2800000              1800000
# 2                         มั่นใจ     2800000              2000000
# 3                         มั่นใจ     2800000              2200000
# 4                         มั่นใจ    14900000              8000000
#
# 0         ปัจจัยในการประเมินราคาซื้อ-ขาย  เหตุผลไม่มั่นใจราคาประเมิน  \
# 0         ปัจจัยในการประเมินราคาซื้อ-ขาย  เหตุผลไม่มั่นใจราคาประเมิน
# ...

# %%
land = land.iloc[1:].reset_index().iloc[:,1:] #ตัดคอลัม

# %%
land.head()
# Out:
# 0 ID ผู้ประเมิน                               post id property_type  \
# 0            02  https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 1            04  https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 2            01  https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# 3            02  https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# 4            04  https://nayoo.co/khonkaen/posts/1711        ที่ดิน
#
# 0 ความมั่นใจในการเมินราคาทรัพย์ ราคาทรัพย์ ประเมินราคาซื้อ-ขาย  \
# 0                        มั่นใจ    2800000             2000000
# 1                        มั่นใจ    2800000             2200000
# 2                        มั่นใจ   14900000             8000000
# 3                        มั่นใจ   14900000            12000000
# 4                     ไม่มั่นใจ   14900000
#
# 0           ปัจจัยในการประเมินราคาซื้อ-ขาย เหตุผลไม่มั่นใจราคาประเมิน  \
# 0    ราคาเสนอขาย 7,000-12,0000 บาท/ตารางวา
# 1                              10000-22000
# ...
